# %% [markdown]
# # HomeWork 02

# %% [markdown]
#  We will extract interesting information from www.topuniversities.com and www.timeshighereducation.com in order to analyse universities ranking from different perspectives.

# %%
# Import libraries
import requests
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import json
import scipy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
from ipywidgets import widgets,interact
import warnings
warnings.filterwarnings('ignore')

# %%
# Helper functions

'''
Aggregating the data by  country and region.

The following function helped us to rank the universities according to the column of wish and according to Countries 
or Regions. Furthermore we also define two functions, CountryStdMean and RegionStdMean which each one creates a 
DataFrame with the mean and std values of the universities of eachy country or region.
'''

## Ranking of the universities according to a country
def country_ranking(column_ranking,data_frame, order=False):
    countrySortResults = data_frame
    
    #Sorting and Indexing the DataFrame
    countrySortResults = countrySortResults.sort_values(['region','country'],ascending=[False,False])
    countrySortResults = countrySortResults.set_index(['region','country'])

    # Here we check if there are some regions  country with only one university in the top as they are already sorted 
    allRegionList = np.unique(data_frame['region'],return_counts=True)[0]
    #allRegionCount = np.unique(data_frame['region'],return_counts=True)[1]
    #allNonUniqueRegionList = np.delete(allRegionList ,np.where(allRegionCount == 1), axis=0)
           
    for j in allRegionList:
        
        countryDF = countrySortResults.loc[j]
        
        #We only concider countries that have multiple universities as it would be usless to sort countries 
        #with only one university
        
        allCountriesList = np.unique(countryDF.index,return_counts=True)[0]
        allCountriesCount = np.unique(countryDF.index,return_counts=True)[1]
        allNonUniqueCountryList = np.delete(allCountriesList ,np.where(allCountriesCount == 1), axis=0)     
        
        for i in allNonUniqueCountryList:
            countrySortResults.loc[j,i] = countrySortResults.loc[j,i].sort_values(column_ranking,ascending=order)
        
    #put the ratio in front
    cols=list(countrySortResults)
    cols.insert(1, cols.pop(cols.index(column_ranking)))
    countrySortResults = countrySortResults.loc[:, cols]
    return countrySortResults

# Function that calculates the mean and std of the column of which by country.
def CountryStdMean(column_ranking,data_frame):
    
    countrySortResults = data_frame    
    countrySortResults = countrySortResults.set_index(['region','country'])
    allRegionList = np.unique(data_frame['region'],return_counts=True)[0]
    
    AllCountries = (np.unique(data_frame['country'],return_counts=True)[0])
    
    #Creating a DataFrame containing the mean and the std for each country   
    CountryMeanStd = pd.DataFrame(index=AllCountries)
    CountryMeanStd['Mean']= ""
    CountryMeanStd['Std'] = ""
    
    for j in allRegionList:
        
        countryDF = countrySortResults.loc[j]        
        allCountriesList = np.unique(countryDF.index,return_counts=True)[0]        
        for k in allCountriesList:
            countryData = countrySortResults.loc[j,k]
            CountryMeanStd.xs(k)['Mean'] = countryData[column_ranking].mean()
            CountryMeanStd.xs(k)['Std'] = countryData[column_ranking].std()
    
    return CountryMeanStd
    
    

# REGION RANKING
def region_ranking(column_ranking, data_frame, order=False):
    
    countrySortResults = data_frame
    # Grouping the dataFrame to have the countries and regions together in the good order
    countrySortResults = countrySortResults.sort_values('region',ascending=False)
    countrySortResults = countrySortResults.sort_values('country',ascending=False)
    countrySortResults = countrySortResults.set_index('region')
    
    # Creationg an array with all the regions presentend in the top 200
    allRegionList = np.unique(data_frame['region'],return_counts=True)[0]
    allRegionCount = np.unique(data_frame['region'],return_counts=True)[1]
    allNonUniqueRegionList = np.delete(allRegionList ,np.where(allRegionCount == 1), axis=0)

    # We take each region one by one, and sort the values inside the region according of the column of which
    for j in allNonUniqueRegionList:
        
        countryDF = countrySortResults.loc[j]
        countrySortResults.loc[j] = countrySortResults.loc[j].sort_values(column_ranking,ascending=order)

    countrySortResults = countrySortResults.set_index('country',append=True)

    cols=list(countrySortResults)
    cols.insert(1, cols.pop(cols.index(column_ranking)))
    countrySortResults = countrySortResults.loc[:, cols]
    return countrySortResults


# Function that calculates the mean and std of the column of which by region.
def regionStdMean(column_ranking, data_frame):
    
    countrySortResults = data_frame
    #DataFrame Processing    
    allRegionList = np.unique(data_frame['region'],return_counts=True)[0]
    
    #Creating a DataFrame containing the mean and the std for each country
    RegionMeanStd = pd.DataFrame(index=(np.unique(countrySortResults['region'],return_counts=True)[0]))
    RegionMeanStd['Mean']= ""
    RegionMeanStd['Std'] = ""
    
    
    countrySortResults = countrySortResults.set_index('region')
    
    # Calculating the mean and std for each region
    for j in allRegionList:
        
        countryDF = countrySortResults.loc[j]
        
        RegionData = countrySortResults.loc[j]
        RegionMeanStd.xs(j)['Mean'] = RegionData[column_ranking].mean()
        RegionMeanStd.xs(j)['Std'] = RegionData[column_ranking].std()
        
    
    return RegionMeanStd

# %% [markdown]
# # 200 top-ranking universties in www.topuniversities.com

# %% [markdown]
# First we needed to recover the data from the site. Using Postman we saw that the data were loaded from an external Json file. We used directly this file to load the data of the main page (ranking) then used the link of each page to access to further information

# %%
#url of the json file found with Interceptor
URL='https://www.topuniversities.com/sites/default/files/qs-rankings-data/357051.txt'
r = requests.get(URL)
page_body = r.text
dic_data = json.loads(page_body)

# %%
#function to get the necessary information on specific sites of each university and create our DataFrame
def number_student_faculty(soup):
    student= soup.find('div', class_='total student')
    if student==None:
        return (float('nan'),float('nan'),float('nan'),float('nan'))
    student_number=student.find('div',class_='number').text
    student_inter= soup.find('div', class_='total inter')
    student_inter_number=student_inter.find('div',class_='number').text
    members=soup.find('div',class_='total faculty')
    if members==None:
        return (float('nan'),float('nan'),float('nan'),float('nan'))
    members_number=members.find('div',class_='number').text
    members_inter=soup.find('div',class_='inter faculty')
    if members_inter==None:
        return (float('nan'),float('nan'),float('nan'),float('nan'))
    members_inter_number=members_inter.find('div',class_='number').text
    
    return (student_number[1:-1],student_inter_number[1:-1],members_number[1:-1],members_inter_number[1:-1])

# %% [markdown]
# As the relevant information is in detailed pages of each university we have to go into the URL of each university in the https://www.topuniversities.com/. With this we will get:
# - Name, rank, country and region,
# - Number of faculty members (international and total)
# - Number of students (international and total)

# %%
relevant_info=['title','country','rank_display','region']
All_country=[]
for i in range(200):
    country_info={}
    URL='https://www.topuniversities.com/'+dic_data['data'][i]['url']
    r = requests.get(URL)
    page_body = r.text
    soup=BeautifulSoup(page_body, 'html.parser')
    for info in relevant_info: 
        country_info[info]=dic_data['data'][i][info]
        
    (country_info['number of students'],country_info['number of international students'],\
     country_info['number of members'],country_info['number of international members'])=number_student_faculty(soup)
    All_country.append(country_info)

#Cleaning the outputs    
All_country_1=pd.DataFrame(data=All_country)
All_country_1=All_country_1.apply(lambda x: x.str.replace(',',''))
All_country_1=All_country_1.apply(lambda x: x.str.replace('=',''))
cols = list(All_country_1)

#put the name in front
cols.insert(0, cols.pop(cols.index('title')))
All_country_1 = All_country_1.loc[:, cols]
All_country_1=All_country_1.apply(pd.to_numeric, errors='ignore')
#adding the ratio recquired
All_country_1['ratio inter student/ all student']=\
            All_country_1['number of international students']/\
            All_country_1['number of students']*100
All_country_1['ratio student/ staff']=All_country_1['number of students']/\
            All_country_1['number of members']
display(All_country_1.head())
# Out:
#                                           title         country  \
# 0   Massachusetts Institute of Technology (MIT)   United States
# 1                           Stanford University   United States
# 2                            Harvard University   United States
# 3  California Institute of Technology (Caltech)   United States
# 4                       University of Cambridge  United Kingdom
#
#    number of international members  number of international students  \
# 0                           1679.0                            3717.0
# 1                           2042.0                            3611.0
# 2                           1311.0                            5266.0
# 3                            350.0                             647.0
# 4                           2278.0                            6699.0
#
#    number of members  number of students  rank_display         region  \
# 0             2982.0             11067.0             1  North America
# 1             4285.0             15878.0             2  North America
# 2             4350.0             22429.0             3  North America
# 3              953.0              2255.0             4  North America
# 4             5490.0             18770.0             5         Europe
#
#    ratio inter student/ all student  ratio student/ staff
# 0                         33.586338              3.711268
# 1                         22.742159              3.705484
# 2                         23.478532              5.156092
# 3                         28.691796              2.366212
# 4                         35.689931              3.418944

# %% [markdown]
# #### We can now answer to the questions:
#
#     - Which are the best universities in term of: (a) ratio between faculty members and students, (b) ratio of international students?
#     - Answer the previous question aggregating the data by (c) country and (d) region.
#
#     We decide to rank in a ascending way the ration between student/staff as we think that having a small ratio would mean that there are more professional to take care of the students. We do not only speak about teachers but more PhD assistents, more labs to do projects, etc.
#
#     We decide that a univesity with a big ratio of international students is better. Indeed a univesity with a high ratio somehow reflex it's worldwide notority. However some factors can explain why a univesity has a very low ratio, like the costs of studing in the univesity, the location, etc.

# %% [markdown]
# ### TOP 20 Univesities according to the ratio Student/Staff

# %%
classement_ratio1=All_country_1.sort_values('ratio student/ staff',ascending=True)
display(classement_ratio1.head(20))
# Out:
#                                                  title         country  \
# 3         California Institute of Technology (Caltech)   United States
# 15                                     Yale University   United States
# 5                                 University of Oxford  United Kingdom
# 4                              University of Cambridge  United Kingdom
# 16                            Johns Hopkins University   United States
# 1                                  Stanford University   United States
# 0          Massachusetts Institute of Technology (MIT)   United States
# 18                          University of Pennsylvania   United States
# 17                                 Columbia University   United States
# 7                              Imperial College London  United Kingdom
# 115                    Technical University of Denmark         Denmark
# 72                            University of Copenhagen         Denmark
# 28                             Northwestern University   United States
# 94                   Lomonosov Moscow State University          Russia
# 71   Pohang University of Science And Technology (P...     South Korea
# 58                                 Ecole Polytechnique          France
# 6                      UCL (University College London)  United Kingdom
# 99                  Washington University in St. Louis   United States
# 146                                   Emory University   United States
# 2                                   Harvard University   United States
#
#      number of international members  number of international students  \
# 3                              350.0                             647.0
# 15                            1708.0                            2469.0
# 5                             2964.0                            7353.0
# 4                             2278.0                            6699.0
# 16                            1061.0                            4105.0
# 1                             2042.0                            3611.0
# 0                             1679.0                            3717.0
# 18                            1383.0                            4250.0
# 17                             913.0                            8105.0
# 7                             2071.0                            8746.0
# 115                            966.0                            2098.0
# 72                            2336.0                            3683.0
# 28                            1141.0                            3422.0
# 94                             373.0                            5098.0
# 71                             113.0                             126.0
# 58                             259.0                             924.0
# 6                             2554.0                           14854.0
# 99                             784.0                            2706.0
# 146                            484.0                            2154.0
# 2                             1311.0                            5266.0
#
#      number of members  number of students  rank_display         region  \
# 3                953.0              2255.0             4  North America
# 15              4940.0             12402.0            16  North America
# 5               6750.0             19720.0             6         Europe
# 4               5490.0             18770.0             5         Europe
# 16              4462.0             16146.0            17  North America
# 1               4285.0             15878.0             2  North America
# 0               2982.0             11067.0             1  North America
# 18              5499.0             20639.0            19  North America
# 17              6189.0             25045.0            18  North America
# 7               3930.0             16090.0             8         Europe
# 115             2117.0              8878.0           116         Europe
# 72              7483.0             32119.0            73         Europe
# 28              4231.0             18675.0            28  North America
# 94              6709.0             30233.0            95         Europe
# 71               664.0              3117.0            71           Asia
# 58               649.0              3126.0            59         Europe
# 6               6345.0             31080.0             7         Europe
# 99              2699.0             13474.0           100  North America
# 146             2560.0             12852.0           147  North America
# 2               4350.0             22429.0             3  North America
#
#      ratio inter student/ all student  ratio student/ staff
# 3                           28.691796              2.366212
# 15                          19.908079              2.510526
# 5                           37.287018              2.921481
# 4                           35.689931              3.418944
# 16                          25.424254              3.618557
# 1                           22.742159              3.705484
# 0                           33.586338              3.711268
# 18                          20.592083              3.753228
# 17                          32.361749              4.046696
# 7                           54.356743              4.094148
# 115                         23.631449              4.193670
# 72                          11.466733              4.292262
# 28                          18.323963              4.413850
# 94                          16.862369              4.506335
# 71                           4.042348              4.694277
# 58                          29.558541              4.816641
# 6                           47.792793              4.898345
# 99                          20.083123              4.992219
# 146                         16.760037              5.020313
# 2                           23.478532              5.156092

# %% [markdown]
# ### TOP 20 Univesities according to the ratio International Student/ All Students

# %%
classement_ratio2=All_country_1.sort_values('ratio inter student/ all student',ascending=False)
display(classement_ratio2.head(20))
# Out:
#                                                  title         country  \
# 34   London School of Economics and Political Scien...  United Kingdom
# 11     Ecole Polytechnique Fédérale de Lausanne (EPFL)     Switzerland
# 7                              Imperial College London  United Kingdom
# 198                              Maastricht University     Netherlands
# 46                          Carnegie Mellon University   United States
# 6                      UCL (University College London)  United Kingdom
# 91                            University of St Andrews  United Kingdom
# 41                         The University of Melbourne       Australia
# 126                    Queen Mary University of London  United Kingdom
# 25                         The University of Hong Kong       Hong Kong
# 23                               King's College London  United Kingdom
# 112                            University of Groningen     Netherlands
# 56                           The University of Warwick  United Kingdom
# 98                                University of Geneva     Switzerland
# 19                  The Australian National University       Australia
# 108                         The University of Adelaide       Australia
# 9    ETH Zurich - Swiss Federal Institute of Techno...     Switzerland
# 22                         The University of Edinburgh  United Kingdom
# 5                                 University of Oxford  United Kingdom
# 33                        The University of Manchester  United Kingdom
#
#      number of international members  number of international students  \
# 34                             687.0                            6748.0
# 11                            1300.0                            5896.0
# 7                             2071.0                            8746.0
# 198                            502.0                            8234.0
# 46                             425.0                            6385.0
# 6                             2554.0                           14854.0
# 91                             485.0                            4030.0
# 41                            1477.0                           18030.0
# 126                            801.0                            6806.0
# 25                            2085.0                            8230.0
# 23                            1513.0                            9451.0
# 112                           1137.0                           10780.0
# 56                             890.0                            7703.0
# 98                            1029.0                            6104.0
# 19                             927.0                            5551.0
# 108                            633.0                            8114.0
# 9                             1886.0                            7563.0
# 22                            1553.0                           10551.0
# 5                             2964.0                            7353.0
# 33                            1653.0                           13514.0
#
#      number of members  number of students  rank_display         region  \
# 34              1088.0              9760.0            35         Europe
# 11              1695.0             10343.0            12         Europe
# 7               3930.0             16090.0             8         Europe
# 198             1277.0             16385.0           200         Europe
# 46              1342.0             13356.0            47  North America
# 6               6345.0             31080.0             7         Europe
# 91              1140.0              8800.0            92         Europe
# 41              3311.0             42182.0            41        Oceania
# 126             1885.0             16135.0           127         Europe
# 25              3012.0             20214.0            26           Asia
# 23              3650.0             23780.0            23         Europe
# 112             3351.0             27549.0           113         Europe
# 56              2093.0             19855.0            57         Europe
# 98              1752.0             15844.0            98         Europe
# 19              1600.0             14442.0            20        Oceania
# 108             1729.0             21240.0           109        Oceania
# 9               2477.0             19815.0            10         Europe
# 22              4075.0             28040.0            23         Europe
# 5               6750.0             19720.0             6         Europe
# 33              4910.0             36670.0            34         Europe
#
#      ratio inter student/ all student  ratio student/ staff
# 34                          69.139344              8.970588
# 11                          57.004738              6.102065
# 7                           54.356743              4.094148
# 198                         50.253280             12.830854
# 46                          47.806229              9.952310
# 6                           47.792793              4.898345
# 91                          45.795455              7.719298
# 41                          42.743350             12.739958
# 126                         42.181593              8.559682
# 25                          40.714356              6.711155
# 23                          39.743482              6.515068
# 112                         39.130277              8.221128
# 56                          38.796273              9.486383
# 98                          38.525625              9.043379
# 19                          38.436505              9.026250
# 108                         38.201507             12.284558
# 9                           38.168055              7.999596
# 22                          37.628388              6.880982
# 5                           37.287018              2.921481
# 33                          36.853013              7.468432

# %% [markdown]
# ### Ratio Student/Staff per country. Here we show 20 Asian univesities.

# %%
Country_ranking1 = country_ranking('ratio student/ staff',All_country_1,True)
display(Country_ranking1.loc['Asia'].head(20))
# Out:
#                                                           title  \
# country
# Taiwan                         National Taiwan University (NTU)
# Taiwan                            National Tsing Hua University
# South Korea   Pohang University of Science And Technology (P...
# South Korea                      Sungkyunkwan University (SKKU)
# South Korea                                    Korea University
# South Korea                           Seoul National University
# South Korea                                   Yonsei University
# South Korea                                  Hanyang University
# South Korea   KAIST - Korea Advanced Institute of Science & ...
# Singapore      Nanyang Technological University Singapore (NTU)
# Singapore                National University of Singapore (NUS)
# Saudi Arabia       King Fahd University of Petroleum & Minerals
# Malaysia                                 Universiti Malaya (UM)
# Japan                                         Tohoku University
# Japan                                          Kyoto University
# Japan                                         Nagoya University
# Japan                                   The University of Tokyo
# Japan                             Tokyo Institute of Technology
# Japan                                         Kyushu University
# Japan                                       Hokkaido University
#
#               ratio student/ staff  number of international members  \
# country
# Taiwan                   11.469540                            220.0
# Taiwan                   13.617647                            119.0
# South Korea               4.694277                            113.0
# South Korea               6.726940                            324.0
# South Korea               6.913752                            339.0
# South Korea               7.140967                            433.0
# South Korea               7.153549                            290.0
# South Korea               7.568233                            364.0
# South Korea               7.860800                            147.0
# Singapore                 5.933149                           2993.0
# Singapore                 6.409714                           3086.0
# Saudi Arabia              5.687382                            665.0
# Malaysia                  6.498004                            655.0
# Japan                     5.226327                            264.0
# Japan                     5.658621                            293.0
# Japan                     5.942964                            206.0
# Japan                     6.043199                            254.0
# Japan                     6.290467                            191.0
# Japan                     6.529041                            246.0
# Japan                     6.737812                            210.0
#
#               number of international students  number of members  \
# country
# Taiwan                                  3152.0             2807.0
# Taiwan                                  1187.0             1020.0
# South Korea                              126.0              664.0
# South Korea                             2818.0             3556.0
# South Korea                             3638.0             3745.0
# South Korea                             2331.0             3930.0
# South Korea                             3379.0             3621.0
# South Korea                             3397.0             3085.0
# South Korea                              584.0             1250.0
# Singapore                               7251.0             4338.0
# Singapore                               8917.0             5106.0
# Saudi Arabia                             989.0             1062.0
# Malaysia                                3476.0             2755.0
# Japan                                   1604.0             3411.0
# Japan                                   1990.0             4060.0
# Japan                                   1547.0             2665.0
# Japan                                   2639.0             4514.0
# Japan                                   1071.0             1563.0
# Japan                                   1787.0             2858.0
# Japan                                   1347.0             2605.0
#
#               number of students  rank_display  \
# country
# Taiwan                   32195.0            76
# Taiwan                   13890.0           161
# South Korea               3117.0            71
# South Korea              23921.0           108
# South Korea              25892.0            90
# South Korea              28064.0            36
# South Korea              25903.0           106
# South Korea              23348.0           155
# South Korea               9826.0            41
# Singapore                25738.0            11
# Singapore                32728.0            15
# Saudi Arabia              6040.0           173
# Malaysia                 17902.0           114
# Japan                    17827.0            76
# Japan                    22974.0            36
# Japan                    15838.0           116
# Japan                    27279.0            28
# Japan                     9832.0            56
# Japan                    18660.0           128
# Japan                    17552.0           122
#
#               ratio inter student/ all student
# country
# Taiwan                                9.790340
# Taiwan                                8.545716
# South Korea                           4.042348
# South Korea                          11.780444
# South Korea                          14.050672
# South Korea                           8.306015
# South Korea                          13.044821
# South Korea                          14.549426
# South Korea                           5.943415
# Singapore                            28.172352
# Singapore                            27.245783
# Saudi Arabia                         16.374172
# Malaysia                             19.416825
# Japan                                 8.997588
# Japan                                 8.661966
# Japan                                 9.767647
# Japan                                 9.674108
# Japan                                10.893002
# Japan                                 9.576635
# Japan                                 7.674339

# %% [markdown]
# ### Ratio international student/total students Per Country. Here we show 30 European univesities.

# %%
Country_ranking2 = country_ranking('ratio inter student/ all student',All_country_1,False)
display(Country_ranking1.loc['Europe'].head(30))
# Out:
#                                                             title  \
# country
# United Kingdom                               University of Oxford
# United Kingdom                            University of Cambridge
# United Kingdom                            Imperial College London
# United Kingdom                    UCL (University College London)
# United Kingdom                              King's College London
# United Kingdom                        The University of Edinburgh
# United Kingdom                              University of Bristol
# United Kingdom                       The University of Manchester
# United Kingdom                           University of St Andrews
# United Kingdom                        The University of Sheffield
# United Kingdom                          University of Southampton
# United Kingdom                    Queen Mary University of London
# United Kingdom                              University of Glasgow
# United Kingdom                       The University of Nottingham
# United Kingdom                                 University of York
# United Kingdom                                 Cardiff University
# United Kingdom                               Newcastle University
# United Kingdom  London School of Economics and Political Scien...
# United Kingdom                             University of Aberdeen
# United Kingdom                            University of Liverpool
# United Kingdom                          The University of Warwick
# United Kingdom                           University of Birmingham
# United Kingdom                                University of Leeds
# United Kingdom                               Lancaster University
# United Kingdom                              University of Reading
# United Kingdom                                  Durham University
# United Kingdom                           The University of Exeter
# United Kingdom                                 University of Bath
# Switzerland                                  University of Zurich
# Switzerland       Ecole Polytechnique Fédérale de Lausanne (EPFL)
#
#                 ratio student/ staff  number of international members  \
# country
# United Kingdom              2.921481                           2964.0
# United Kingdom              3.418944                           2278.0
# United Kingdom              4.094148                           2071.0
# United Kingdom              4.898345                           2554.0
# United Kingdom              6.515068                           1513.0
# United Kingdom              6.880982                           1553.0
# United Kingdom              7.188153                            942.0
# United Kingdom              7.468432                           1653.0
# United Kingdom              7.719298                            485.0
# United Kingdom              8.296900                            938.0
# United Kingdom              8.430851                           1017.0
# United Kingdom              8.559682                            801.0
# United Kingdom              8.581982                            956.0
# United Kingdom              8.680060                           1135.0
# United Kingdom              8.728314                            636.0
# United Kingdom              8.916515                            705.0
# United Kingdom              8.926277                            835.0
# United Kingdom              8.970588                            687.0
# United Kingdom              9.164122                            508.0
# United Kingdom              9.232218                            717.0
# United Kingdom              9.486383                            890.0
# United Kingdom              9.675895                           1028.0
# United Kingdom              9.800000                            870.0
# United Kingdom              9.879518                            435.0
# United Kingdom             10.414062                            422.0
# United Kingdom             10.880442                            586.0
# United Kingdom             11.816059                            597.0
# United Kingdom             12.334764                            440.0
# Switzerland                 5.216130                           2617.0
# Switzerland                 6.102065                           1300.0
#
#                 number of international students  number of members  \
# country
# United Kingdom                            7353.0             6750.0
# United Kingdom                            6699.0             5490.0
# United Kingdom                            8746.0             3930.0
# United Kingdom                           14854.0             6345.0
# United Kingdom                            9451.0             3650.0
# United Kingdom                           10551.0             4075.0
# United Kingdom                            5099.0             2870.0
# United Kingdom                           13514.0             4910.0
# United Kingdom                            4030.0             1140.0
# United Kingdom                            8745.0             3065.0
# United Kingdom                            7789.0             2820.0
# United Kingdom                            6806.0             1885.0
# United Kingdom                            8149.0             2775.0
# United Kingdom                            7993.0             3360.0
# United Kingdom                            3364.0             1833.0
# United Kingdom                            6090.0             2755.0
# United Kingdom                            5717.0             2428.0
# United Kingdom                            6748.0             1088.0
# United Kingdom                            4246.0             1310.0
# United Kingdom                            7502.0             2390.0
# United Kingdom                            7703.0             2093.0
# United Kingdom                            7795.0             2962.0
# United Kingdom                            7534.0             3025.0
# United Kingdom                            4464.0             1245.0
# United Kingdom                            4077.0             1280.0
# United Kingdom                            4690.0             1539.0
# United Kingdom                            5504.0             1756.0
# United Kingdom                            4213.0             1165.0
# Switzerland                               5036.0             4997.0
# Switzerland                               5896.0             1695.0
#
#                 number of students  rank_display  \
# country
# United Kingdom             19720.0             6
# United Kingdom             18770.0             5
# United Kingdom             16090.0             8
# United Kingdom             31080.0             7
# United Kingdom             23780.0            23
# United Kingdom             28040.0            23
# United Kingdom             20630.0            44
# United Kingdom             36670.0            34
# United Kingdom              8800.0            92
# United Kingdom             25430.0            82
# United Kingdom             23775.0           102
# United Kingdom             16135.0           127
# United Kingdom             23815.0            65
# United Kingdom             29165.0            84
# United Kingdom             15999.0           135
# United Kingdom             24565.0           137
# United Kingdom             21673.0           161
# United Kingdom              9760.0            35
# United Kingdom             12005.0           158
# United Kingdom             22065.0           173
# United Kingdom             19855.0            57
# United Kingdom             28660.0            84
# United Kingdom             29645.0           101
# United Kingdom             12300.0           135
# United Kingdom             13330.0           188
# United Kingdom             16745.0            78
# United Kingdom             20749.0           158
# United Kingdom             14370.0           160
# Switzerland                26065.0            73
# Switzerland                10343.0            12
#
#                 ratio inter student/ all student
# country
# United Kingdom                         37.287018
# United Kingdom                         35.689931
# United Kingdom                         54.356743
# United Kingdom                         47.792793
# United Kingdom                         39.743482
# United Kingdom                         37.628388
# United Kingdom                         24.716432
# United Kingdom                         36.853013
# United Kingdom                         45.795455
# United Kingdom                         34.388517
# United Kingdom                         32.761304
# United Kingdom                         42.181593
# United Kingdom                         34.217930
# United Kingdom                         27.406137
# United Kingdom                         21.026314
# United Kingdom                         24.791370
# United Kingdom                         26.378443
# United Kingdom                         69.139344
# United Kingdom                         35.368596
# United Kingdom                         33.999547
# United Kingdom                         38.796273
# United Kingdom                         27.198186
# United Kingdom                         25.414066
# United Kingdom                         36.292683
# United Kingdom                         30.585146
# United Kingdom                         28.008361
# United Kingdom                         26.526580
# United Kingdom                         29.318024
# Switzerland                            19.320928
# Switzerland                            57.004738

# %% [markdown]
# ### Ratio Student/Staff per region . Here we show 20 North America univesities.

# %%
Region_ranking1=region_ranking('ratio student/ staff',All_country_1,True) #choose from cols=list(countrySortResults)
display(Region_ranking1.loc['North America'].head(20))
# Out:
#                                                       title  \
# country
# United States  California Institute of Technology (Caltech)
# United States                               Yale University
# United States                      Johns Hopkins University
# United States                           Stanford University
# United States   Massachusetts Institute of Technology (MIT)
# United States                    University of Pennsylvania
# United States                           Columbia University
# United States                       Northwestern University
# United States            Washington University in St. Louis
# United States                              Emory University
# United States                            Harvard University
# United States                               Duke University
# United States                         University of Chicago
# United States      University of North Carolina Chapel Hill
# United States                        University of Michigan
# United States                             Dartmouth College
# United States               University of Wisconsin-Madison
# United States                               Rice University
# United States                              Brown University
# United States                     The Ohio State University
#
#                ratio student/ staff  number of international members  \
# country
# United States              2.366212                            350.0
# United States              2.510526                           1708.0
# United States              3.618557                           1061.0
# United States              3.705484                           2042.0
# United States              3.711268                           1679.0
# United States              3.753228                           1383.0
# United States              4.046696                            913.0
# United States              4.413850                           1141.0
# United States              4.992219                            784.0
# United States              5.020313                            484.0
# United States              5.156092                           1311.0
# United States              5.214432                            226.0
# United States              5.535729                            635.0
# United States              6.214303                            524.0
# United States              6.336760                           1920.0
# United States              6.628328                             27.0
# United States              6.813177                           1151.0
# United States              6.821465                            316.0
# United States              7.099770                            379.0
# United States              7.300964                           1696.0
#
#                number of international students  number of members  \
# country
# United States                             647.0              953.0
# United States                            2469.0             4940.0
# United States                            4105.0             4462.0
# United States                            3611.0             4285.0
# United States                            3717.0             2982.0
# United States                            4250.0             5499.0
# United States                            8105.0             6189.0
# United States                            3422.0             4231.0
# United States                            2706.0             2699.0
# United States                            2154.0             2560.0
# United States                            5266.0             4350.0
# United States                            2864.0             2938.0
# United States                            3379.0             2449.0
# United States                            1934.0             4083.0
# United States                            7527.0             6809.0
# United States                             945.0              939.0
# United States                            4920.0             5722.0
# United States                            1847.0              969.0
# United States                            1825.0             1303.0
# United States                            6874.0             5911.0
#
#                number of students  rank_display  \
# country
# United States              2255.0             4
# United States             12402.0            16
# United States             16146.0            17
# United States             15878.0             2
# United States             11067.0             1
# United States             20639.0            19
# United States             25045.0            18
# United States             18675.0            28
# United States             13474.0           100
# United States             12852.0           147
# United States             22429.0             3
# United States             15320.0            21
# United States             13557.0             9
# United States             25373.0            80
# United States             43147.0            21
# United States              6224.0           169
# United States             38985.0            55
# United States              6610.0            89
# United States              9251.0            53
# United States             43156.0            86
#
#                ratio inter student/ all student
# country
# United States                         28.691796
# United States                         19.908079
# United States                         25.424254
# United States                         22.742159
# United States                         33.586338
# United States                         20.592083
# United States                         32.361749
# United States                         18.323963
# United States                         20.083123
# United States                         16.760037
# United States                         23.478532
# United States                         18.694517
# United States                         24.924393
# United States                          7.622276
# United States                         17.445014
# United States                         15.183162
# United States                         12.620239
# United States                         27.942511
# United States                         19.727597
# United States                         15.928260

# %% [markdown]
# ## Ratio International Students/All Students per region . Here we show 20 European univesities.

# %%
Region_ranking2=region_ranking('ratio inter student/ all student',All_country_1,False)
display(Region_ranking2.loc['Europe'].head(20))
# Out:
#                                                             title  \
# country
# United Kingdom  London School of Economics and Political Scien...
# Switzerland       Ecole Polytechnique Fédérale de Lausanne (EPFL)
# United Kingdom                            Imperial College London
# Netherlands                                 Maastricht University
# United Kingdom                    UCL (University College London)
# United Kingdom                           University of St Andrews
# United Kingdom                    Queen Mary University of London
# United Kingdom                              King's College London
# Netherlands                               University of Groningen
# United Kingdom                          The University of Warwick
# Switzerland                                  University of Geneva
# Switzerland     ETH Zurich - Swiss Federal Institute of Techno...
# United Kingdom                        The University of Edinburgh
# United Kingdom                               University of Oxford
# United Kingdom                       The University of Manchester
# United Kingdom                               Lancaster University
# United Kingdom                            University of Cambridge
# United Kingdom                             University of Aberdeen
# United Kingdom                        The University of Sheffield
# United Kingdom                              University of Glasgow
#
#                 ratio inter student/ all student  \
# country
# United Kingdom                         69.139344
# Switzerland                            57.004738
# United Kingdom                         54.356743
# Netherlands                            50.253280
# United Kingdom                         47.792793
# United Kingdom                         45.795455
# United Kingdom                         42.181593
# United Kingdom                         39.743482
# Netherlands                            39.130277
# United Kingdom                         38.796273
# Switzerland                            38.525625
# Switzerland                            38.168055
# United Kingdom                         37.628388
# United Kingdom                         37.287018
# United Kingdom                         36.853013
# United Kingdom                         36.292683
# United Kingdom                         35.689931
# United Kingdom                         35.368596
# United Kingdom                         34.388517
# United Kingdom                         34.217930
#
#                 number of international members  \
# country
# United Kingdom                            687.0
# Switzerland                              1300.0
# United Kingdom                           2071.0
# Netherlands                               502.0
# United Kingdom                           2554.0
# United Kingdom                            485.0
# United Kingdom                            801.0
# United Kingdom                           1513.0
# Netherlands                              1137.0
# United Kingdom                            890.0
# Switzerland                              1029.0
# Switzerland                              1886.0
# United Kingdom                           1553.0
# United Kingdom                           2964.0
# United Kingdom                           1653.0
# United Kingdom                            435.0
# United Kingdom                           2278.0
# United Kingdom                            508.0
# United Kingdom                            938.0
# United Kingdom                            956.0
#
#                 number of international students  number of members  \
# country
# United Kingdom                            6748.0             1088.0
# Switzerland                               5896.0             1695.0
# United Kingdom                            8746.0             3930.0
# Netherlands                               8234.0             1277.0
# United Kingdom                           14854.0             6345.0
# United Kingdom                            4030.0             1140.0
# United Kingdom                            6806.0             1885.0
# United Kingdom                            9451.0             3650.0
# Netherlands                              10780.0             3351.0
# United Kingdom                            7703.0             2093.0
# Switzerland                               6104.0             1752.0
# Switzerland                               7563.0             2477.0
# United Kingdom                           10551.0             4075.0
# United Kingdom                            7353.0             6750.0
# United Kingdom                           13514.0             4910.0
# United Kingdom                            4464.0             1245.0
# United Kingdom                            6699.0             5490.0
# United Kingdom                            4246.0             1310.0
# United Kingdom                            8745.0             3065.0
# United Kingdom                            8149.0             2775.0
#
#                 number of students  rank_display  ratio student/ staff
# country
# United Kingdom              9760.0            35              8.970588
# Switzerland                10343.0            12              6.102065
# United Kingdom             16090.0             8              4.094148
# Netherlands                16385.0           200             12.830854
# United Kingdom             31080.0             7              4.898345
# United Kingdom              8800.0            92              7.719298
# United Kingdom             16135.0           127              8.559682
# United Kingdom             23780.0            23              6.515068
# Netherlands                27549.0           113              8.221128
# United Kingdom             19855.0            57              9.486383
# Switzerland                15844.0            98              9.043379
# Switzerland                19815.0            10              7.999596
# United Kingdom             28040.0            23              6.880982
# United Kingdom             19720.0             6              2.921481
# United Kingdom             36670.0            34              7.468432
# United Kingdom             12300.0           135              9.879518
# United Kingdom             18770.0             5              3.418944
# United Kingdom             12005.0           158              9.164122
# United Kingdom             25430.0            82              8.296900
# United Kingdom             23815.0            65              8.581982

# %% [markdown]
# ## Ploting the data

# %%
countrySTDMEAN = CountryStdMean('ratio student/ staff',All_country_1)
plt.subplot(1, 2, 1)
countrySTDMEAN['Mean'].plot.bar(yerr=countrySTDMEAN['Std'], figsize=(8,8), fontsize = 12,title='Country mean student/ staff ratio in www.topuniversities.com')

RegionSTDMEAN = regionStdMean('ratio student/ staff', All_country_1)
plt.subplot(1, 2, 2)
RegionSTDMEAN['Mean'].plot.bar(yerr=RegionSTDMEAN['Std'],figsize=(18,8), fontsize = 12, title='Region mean student/ staff Ratio in www.topuniversities.com')
plt.show()

# %% [markdown]
# ## Histogram Ratio Student/ Staff Analysis
#
# The country ratio histogram shows us the mean of the student/staff ratio per country with the std. Notice that if there is no std, it's because the countries concerned just have one university in the top 200.
# In a general way we can see that the mean value of the top countries, i.e. countries with universities in the top 20 (United States, Canada, United Kingdom, Switzerland), have a lower mean compared to the general tendency. For this analysis, we don't consider countries without std as they may not be representative of their own country.
# Austria has the highest mean ratio and a large std, this could suggest that the Austrians consider more the university as a place to study rather than a place to work.
#
# The Region ratio histogram shows us that the regions that contains the most universities in the top 200 have a lower mean. This point highlights the importance of the ratio student/staff for the establishment of the ranking. The high std of Europe can be explained by the amount of countries that belong to the region. Indeed, each country has it's own politics regarding university' decision. The same reasoning can be made for the North America as each state has their own laws and education system.
# In a general way the Regions have a similar mean, as the minimal values of the ratio is of 8 and the max is 13.

# %%
countrySTDMEAN = CountryStdMean('ratio inter student/ all student',All_country_1)
plt.subplot(1, 2, 1)
countrySTDMEAN['Mean'].plot.bar(yerr=countrySTDMEAN['Std'], figsize=(8,8), fontsize = 12, title='Country mean ratio inter student/ all student in www.topuniversities.com')

RegionSTDMEAN = regionStdMean('ratio inter student/ all student', All_country_1)
plt.subplot(1, 2, 2)
RegionSTDMEAN['Mean'].plot.bar(yerr=RegionSTDMEAN['Std'],figsize=(18,8), fontsize = 12, title='Region mean ratio inter student/ all student in www.topuniversities.com')
plt.show()

# %% [markdown]
# ## Histogram Ratio Student/ Staff Analysis
#
# The Country ratio histogram varies a lot within countries, there are countries as India, Brazil, Chile that almost don't have international students, whereas Switzerland, United Kingdom, Australia, Austria have a huge percentage of international students in their universities.
#
# The region ratio histogram shows us that there are huge differences between different regions in the world. Indeed,  Latin America has a ratio 6 times lower than Oceania. We see that Europe and North America have values that are in the mean of all the regions. As stated before their high std is not only due to the large number of universities present in the top 200 but also related to the fact that they are composed of several countries for the Europe and several states with their own laws in the North America countries.

# %% [markdown]
# ## Ranking according by number of university in top 200

# %%
display(All_country_1['country'].value_counts())
labels = np.append(All_country_1['country'].value_counts().index[:8].values,'Others')
patch,text,autotexts = plt.pie(np.append(All_country_1['country'].value_counts()[:8].values,np.sum(All_country_1['country'].value_counts()[8:])), autopct='%1.f%%',shadow=True, startangle=90)
plt.legend(patch, labels, loc="best")
plt.axis('equal')
plt.title('Percentage of university per country')
plt.tight_layout()
plt.show()
# Out:
# United States     47
# United Kingdom    28
# Germany           11
# Netherlands       10
# Australia          9
# Japan              9
# Switzerland        7
# South Korea        7
# China              7
# Canada             7
# Hong Kong          5
# France             5
# Sweden             5
# Italy              4
# Belgium            4
# Denmark            3
# India              3
# Spain              3
# Mexico             2
# Ireland            2
# Austria            2
# Brazil             2
# Finland            2
# Norway             2
# Taiwan             2
# Chile              2
# Singapore          2
# New Zealand        2
# South Africa       1
# Malaysia           1
# Saudi Arabia       1
# Argentina          1
# Russia             1
# Israel             1
# Name: country, dtype: int64

# %%
display(All_country_1['region'].value_counts())
labels = All_country_1['region'].value_counts().index
patch,text,autotexts = plt.pie(All_country_1['region'].value_counts(), autopct='%1.f%%',shadow=True, startangle=90)
plt.legend(patch, labels, loc="best")
plt.title('Percentage of university per region')
plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# Europe           89
# North America    54
# Asia             38
# Oceania          11
# Latin America     7
# Africa            1
# Name: region, dtype: int64

# %% [markdown]
# ## 200 top-ranking universities in www.timeshighereducation.com

# %%
#url of the json file 
URL='https://www.timeshighereducation.com/sites/default/files/the_data_rankings/world_university_rankings_2018_limit0_369a9045a203e176392b9fb8f8c1cb2a.json'
r = requests.get(URL)
page_body = r.text

dic_data = json.loads(page_body)

# %%
All_country=[]
for i in range(200):
    country_info={}
    relevant_info=['name','location','rank']
    for info in relevant_info:
        country_info[info]=dic_data['data'][i][info]
    url='https://www.timeshighereducation.com/'+dic_data['data'][i]['url']
    r = requests.get(url)
    page_body = r.text
    soup=BeautifulSoup(page_body, 'html.parser')

    stat= soup.find('div', class_='panel-pane pane-data-stats')
    data_given={}
    for a in stat.find_all('div',class_='value'):
        country_info[a.next_sibling.text]=a.text
    All_country.append(country_info)
All_country_2=pd.DataFrame(data=All_country)
All_country_2 =All_country_2.apply(lambda x: x.str.replace(',',''))
All_country_2=All_country_2.apply(lambda x: x.str.replace('=',''))
All_country_2=All_country_2.apply(lambda x: x.str.replace('%',''))
All_country_2=All_country_2.apply(pd.to_numeric, errors='ignore')
All_country_2 = All_country_2.rename(columns=lambda x: x.replace('location', 'country'))
All_country_2 = All_country_2.rename(columns=lambda x: x.replace('name', 'title'))
cols=list(All_country_2)
cols.pop(cols.index('Out-of-state Tuition and Fees'))
cols.pop(cols.index('On-campus Room and Board'))
cols.pop(cols.index('Salary after 10 years'))
cols.insert(0, cols.pop(cols.index('title')))
All_country_2= All_country_2.loc[:, cols]
All_country_3 = All_country_2

display(All_country_2.head())
# Out:
#                                    title  No. of students per staff  \
# 0                   University of Oxford                       11.2
# 1                University of Cambridge                       10.9
# 2     California Institute of Technology                        6.5
# 3                    Stanford University                        7.5
# 4  Massachusetts Institute of Technology                        8.7
#
#    Number of Students  Percentage of International Students  \
# 0               20409                                    38
# 1               18389                                    35
# 2                2209                                    27
# 3               15845                                    22
# 4               11177                                    34
#
#   Student Ratio of Females to Males         country  rank
# 0                           46 : 54  United Kingdom     1
# 1                           45 : 55  United Kingdom     2
# 2                           31 : 69   United States     3
# 3                           42 : 58   United States     3
# 4                           37 : 63   United States     5

# %%
#Mapping with the region of dataframe 1
country_region={}
country_region['Luxembourg'] = 'Europe'
country_region['Russian Federation'] = 'Europe'

for country in All_country_1['country'].unique():
    spec_country=All_country_1.loc[All_country_1['country'] == country]
    region=spec_country['region'].unique()
    country_region[country]=region[0]

All_country_2['region']=[country_region[x] for x in All_country_2['country']]

# %% [markdown]
# we can now repeat the analysis as we did before.
# - Which are the best universities in term of: (a) ratio between faculty members and students, (b) ratio of international students?
# - Answer the previous question aggregating the data by (c) country and (d) region.

# %% [markdown]
# ## Aggregating the data by  country and region.
#
# The following function helped us to rank the universities according to the column of wish and according to Countries or Regions. Furthermore we also define two functions, CountryStdMean and RegionStdMean which each one creates a DataFrame with the mean and std values of the universities of eachy country or region.

# %%
classement_ratio1=All_country_2.sort_values('No. of students per staff',ascending=True)
display(classement_ratio1.head())
classement_ratio2=All_country_2.sort_values('Percentage of International Students',ascending=False)
display(classement_ratio2.head())
# Out:
#                         title  No. of students per staff  Number of Students  \
# 105     Vanderbilt University                        3.3               12011
# 109  University of Copenhagen                        4.1               30395
# 12   Johns Hopkins University                        4.3               15498
# 11            Yale University                        4.3               12155
# 153   University of Rochester                        4.3                9636
#
#      Percentage of International Students Student Ratio of Females to Males  \
# 105                                    13                           53 : 47
# 109                                    14                           58 : 42
# 12                                     24                           52 : 48
# 11                                     21                           49 : 51
# 153                                    29                           49 : 51
#
#            country  rank         region
# 105  United States   105  North America
# 109        Denmark   109         Europe
# 12   United States    13  North America
# 11   United States    12  North America
# 153  United States   153  North America
#                                                 title  \
# 24   London School of Economics and Political Science
# 178                          University of Luxembourg
# 37           École Polytechnique Fédérale de Lausanne
# 7                             Imperial College London
# 102                             Maastricht University
#
#      No. of students per staff  Number of Students  \
# 24                        12.2               10065
# 178                       14.6                4969
# 37                        11.2                9928
# 7                         11.4               15857
# 102                       18.0               16727
#
#      Percentage of International Students Student Ratio of Females to Males  \
# 24                                     71                           52 : 48
# 178                                    57                           50 : 50
# 37                                     55                           28 : 72
# 7                                      55                           37 : 63
# 102                                    50                           58 : 42
#
#             country  rank  region
# 24   United Kingdom    25  Europe
# 178      Luxembourg   179  Europe
# 37      Switzerland    38  Europe
# 7    United Kingdom     8  Europe
# 102     Netherlands   103  Europe

# %%
#the ranking is done inside a country as before (which uni is the best of a country)
country_ranking1 = country_ranking('No. of students per staff',All_country_2, True)
country_ranking2=country_ranking('Percentage of International Students',All_country_2, False)
display(country_ranking1.head())
display(country_ranking2.head())
#ranking is made inside regions now (which uni is the best of a region)
region_ranking1 = region_ranking('No. of students per staff',All_country_2, True)
region_ranking2=region_ranking('Percentage of International Students',All_country_2, False)
display(region_ranking1.head())
display(region_ranking2.head())
# Out:
#                                                title  \
# region  country
# Oceania New Zealand           University of Auckland
#         Australia     Australian National University
#         Australia               University of Sydney
#         Australia    University of Western Australia
#         Australia            University of Melbourne
#
#                      No. of students per staff  Number of Students  \
# region  country
# Oceania New Zealand                       18.8               30348
#         Australia                         19.3               15986
#         Australia                         21.6               44553
#         Australia                         21.8               18787
#         Australia                         26.6               42116
#
#                      Percentage of International Students  \
# region  country
# Oceania New Zealand                                    29
#         Australia                                      35
#         Australia                                      32
#         Australia                                      25
#         Australia                                      40
#
#                     Student Ratio of Females to Males  rank
# region  country
# Oceania New Zealand                           54 : 46   192
#         Australia                             52 : 48    48
#         Australia                             57 : 43    61
#         Australia                             49 : 51   111
#         Australia                             55 : 45    32
#                                               title  \
# region  country
# Oceania New Zealand          University of Auckland
#         Australia           University of Melbourne
#         Australia    Australian National University
#         Australia     University of New South Wales
#         Australia              University of Sydney
#
#                      Percentage of International Students  \
# region  country
# Oceania New Zealand                                    29
#         Australia                                      40
#         Australia                                      35
#         Australia                                      34
#         Australia                                      32
#
#                      No. of students per staff  Number of Students  \
# region  country
# Oceania New Zealand                       18.8               30348
#         Australia                         26.6               42116
#         Australia                         19.3               15986
#         Australia                         26.7               40133
#         Australia                         21.6               44553
#
#                     Student Ratio of Females to Males  rank
# region  country
# Oceania New Zealand                           54 : 46   192
#         Australia                             55 : 45    32
#         Australia                             52 : 48    48
#         Australia                             46 : 54    85
#         Australia                             57 : 43    61
#                                                 title  \
# region        country
# North America United States     Vanderbilt University
#               United States   University of Rochester
#               United States           Yale University
#               United States  Johns Hopkins University
#               United States          Emory University
#
#                              No. of students per staff  Number of Students  \
# region        country
# North America United States                        3.3               12011
#               United States                        4.3                9636
#               United States                        4.3               12155
#               United States                        4.3               15498
#               United States                        4.4               12649
#
#                              Percentage of International Students  \
# region        country
# North America United States                                    13
#               United States                                    29
#               United States                                    21
#               United States                                    24
#               United States                                    19
#
#                             Student Ratio of Females to Males  rank
# region        country
# North America United States                           53 : 47   105
#               United States                           49 : 51   153
#               United States                           49 : 51    12
#               United States                           52 : 48    13
#               United States                           57 : 43    98
#                                                              title  \
# region        country
# North America United States             Carnegie Mellon University
#               United States  Massachusetts Institute of Technology
#               United States                    Columbia University
#               United States                Northeastern University
#               Canada                University of British Columbia
#
#                              Percentage of International Students  \
# region        country
# North America United States                                    45
#               United States                                    34
#               United States                                    32
#               United States                                    32
#               Canada                                           29
#
#                              No. of students per staff  Number of Students  \
# region        country
# North America United States                       13.5               12676
#               United States                        8.7               11177
#               United States                        6.1               26587
#               United States                       14.0               18780
#               Canada                              18.1               51889
#
#                             Student Ratio of Females to Males  rank
# region        country
# North America United States                           39 : 61    24
#               United States                           37 : 63     5
#               United States                               NaN    14
#               United States                           49 : 51   193
#               Canada                                  54 : 46    34

# %% [markdown]
# ## Ploting the data

# %%
countrySTDMEAN = CountryStdMean('Percentage of International Students',All_country_2)
plt.subplot(1, 2, 1)
countrySTDMEAN['Mean'].plot.bar(yerr=countrySTDMEAN['Std'], figsize=(8,8), fontsize = 12, title = 'Country mean ratio inter student/ all student in www.timeshighereducation.com' )

RegionSTDMEAN = regionStdMean('Percentage of International Students', All_country_2)
plt.subplot(1, 2, 2)
RegionSTDMEAN['Mean'].plot.bar(yerr=RegionSTDMEAN['Std'],figsize=(18,8), fontsize = 12, title = 'Region mean ratio inter student/ all student in www.timeshighereducation.com')
plt.show()

# %% [markdown]
# ## Histogram Ratio International Student/ All Students Analysis
#
# This country mean ratio histogram brings us a new insight for the analysis of the university ranking, which is the outliers, indeed in www.timeshighereducation.com ranking Luxembourg belongs to the top 200. However, it's well-founded to ask if can we treat this country in the same way as other, knowing that it only contains a population about 500000 residents.
#
# For the region mean ration, the same analyse can be made, as there are no new insights

# %%
countrySTDMEAN = CountryStdMean('No. of students per staff',All_country_2)
plt.subplot(1, 2, 1)
countrySTDMEAN['Mean'].plot.bar(yerr=countrySTDMEAN['Std'], figsize=(8,8), fontsize = 12, title = 'Country mean ratio of students/staff in www.timeshighereducation.com' )
#Histogram Ratio Student/ Staff Analysis
RegionSTDMEAN = regionStdMean('No. of students per staff', All_country_2)
plt.subplot(1, 2, 2)
RegionSTDMEAN['Mean'].plot.bar(yerr=RegionSTDMEAN['Std'],figsize=(18,8), fontsize = 12, title = 'Region mean ratio of students/staff in www.timeshighereducation.com')
plt.show()

# %% [markdown]
# ## Histogram Ratio Student/ Staff Analysis
#
# The Country ratio histogram varies a lot within countries, but still there is a general tendency that evolves from 12 to 20 students per staff. In this webpage ranking there are less universities outliers that almost the same amount of student than staff as the previous ranking page.
#
# This region ratio histogram varies much less than the previous ranking page, but we can still see that both have the same tendency i.e. Oceania has the largest average of student/staff and Europe has a large std.

# %% [markdown]
# ## Ranking according to number of university in top 200

# %%
display(All_country_2['country'].value_counts())

labels = np.append(All_country_2['country'].value_counts().index[:8].values,'Others')
patch,text,autotexts = plt.pie(np.append(All_country_2['country'].value_counts()[:8].values,np.sum(All_country_2['country'].value_counts()[8:])), autopct='%1.f%%',shadow=True, startangle=90)
plt.legend(patch, labels, loc="best")
plt.axis('equal')
plt.title('Percentage of university per country')
plt.tight_layout()
plt.show()
# Out:
# United States         62
# United Kingdom        31
# Germany               20
# Netherlands           13
# Australia              8
# Switzerland            7
# China                  7
# Sweden                 6
# France                 6
# Canada                 6
# Hong Kong              5
# South Korea            4
# Belgium                4
# Denmark                3
# Singapore              2
# Japan                  2
# Italy                  2
# Finland                2
# Spain                  2
# Austria                1
# Norway                 1
# Taiwan                 1
# Russian Federation     1
# Ireland                1
# South Africa           1
# Luxembourg             1
# New Zealand            1
# Name: country, dtype: int64

# %%
display(All_country_2['region'].value_counts())

labels = All_country_2['region'].value_counts().index
patch,text,autotexts = plt.pie(All_country_2['region'].value_counts(), autopct='%1.f%%',shadow=True, startangle=90)
plt.legend(patch, labels, loc="best")
plt.title('Percentage of university per region')
plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# Europe           101
# North America     68
# Asia              21
# Oceania            9
# Africa             1
# Name: region, dtype: int64

# %% [markdown]
# ## Interactive display (Need to run the code)

# %%
def f(Region,Dataset,Sorting_by):
    if (Dataset == True):
        if (Sorting_by == True):
            display(All_country_1.groupby('region').get_group(Region).sort_values('ratio student/ staff'))
        else :
            display(All_country_1.groupby('region').get_group(Region).sort_values('ratio inter student/ all student'))
    else :
        if (Sorting_by == True):
            display(All_country_2.groupby('region').get_group(Region).sort_values('No. of students per staff'))
        else :
            display(All_country_2.groupby('region').get_group(Region).sort_values('Percentage of International Students'))

# Function interact to implement interactive display
interact(f, Region =np.unique(All_country_1['region']), Dataset = {'Top Universities' : True, 'Time Higher Education' : False}, Sorting_by ={'Ratio student/staff' : True,'Ratio international/ all student' :False})
# Out:
# <function __main__.f>

# %% [markdown]
# ## Merging the DataFrame

# %% [markdown]
# Match universities' names as well as you can, and explain your strategy
#
# - To merge the two dataframes, we should modify the name and create a "merging" criteria since some universities' name were a bit different.
#
# - First of all, we deleted all common word such as "for, a, of, ..." and split the university name in separated words.
#
# - Then, we created a "merging label" composed of the first 3 words of the university name. We decided to take the first 3 words to have a higher accuracy in the merging.
#
# - Using the function pd.merge on the 2 dataset using the feature "merging" as a criteria for merging.
#
# - Finally, after fixing some exceptions, we delete the universities which were not in both ranking.

# %%
stoplist = set('for a of the and to in - –'.split()) # List of common words

texts = [[word for word in title.lower().split() if word not in stoplist] # Split the name in separated words
        for title in All_country_1['title']]
All_country_1['merging'] = texts

texts2 = [[word for word in title.lower().split() if word not in stoplist]
        for title in All_country_2['title']]
All_country_2['merging'] = texts2

All_country_1['merging'] = All_country_1['merging'].apply(lambda x: ' '.join(map(str, x[:3]))) # Creating a new features with the first 3 words of the name
All_country_2['merging'] = All_country_2['merging'].apply(lambda x: ' '.join(map(str, x[:3]))) 

All_country_1['merging'] = All_country_1['merging'].replace('ucl (university college','university college london') # Replace manually for some execptions
All_country_2['merging'] = All_country_2['merging'].replace('école polytechnique fédérale','ecole polytechnique fédérale')

Rank = pd.merge(All_country_1, All_country_2,  how='outer', on=['merging']) # Merging using feature 'merging'

# This block of code is to add the value when the country of the title is missing
Rank['title_x'] = Rank['title_x'].replace(np.nan,0)
Rank['country_x'] = Rank['country_x'].replace(np.nan,0)
School_name = []
Country = []

for i,name in enumerate(Rank['title_x'].values) :
    if (name != 0) :
        School_name.append(name)
    else :
        School_name.append(Rank['title_y'].values[i])
Rank['School name'] = School_name

for i,name in enumerate(Rank['country_x'].values) :
    if (name != 0) :
        Country.append(name)
    else :
        Country.append(Rank['country_y'].values[i])
Rank['Country'] = Country

Rank.drop(['title_y','title_x','country_y','country_x'] ,axis=1,inplace=True)

Rank['rank_display'] = Rank['rank_display'].replace(np.nan,999)
Rank['rank'] = Rank['rank'].replace(np.nan,999)

# Cre
Rank_final = pd.DataFrame({'1 - School Name' : Rank['School name'],
                     '2 - Rank #1' : Rank['rank_display'],
                     '3 - Rank #2' : Rank['rank'],
                     '4 - Country' : Rank['Country'],
                     '5 - Region' : Rank['region_x'],
                     '6 - Percentage of international #1' : round(Rank['ratio inter student/ all student']), 
                     '7 - Percentage of international #2' : Rank['Percentage of International Students'],
                     '8 - Ratio Student /Staff #1' : Rank['ratio student/ staff'],
                     '9 - Ratio Student /Staff #2' : Rank['No. of students per staff'],
                     '10 - Number of students': Rank['Number of Students']})

Rank_final.drop(Rank_final.loc[Rank_final['2 - Rank #1'] == 999].index,inplace=True) # Drop the school when they are not in both rankings.
Rank_final.drop(Rank_final.loc[Rank_final['3 - Rank #2'] == 999].index,inplace=True)

display(Rank_final)
# Out:
#                                        1 - School Name  \
# 0          Massachusetts Institute of Technology (MIT)
# 1                                  Stanford University
# 2                                   Harvard University
# 3         California Institute of Technology (Caltech)
# 4                              University of Cambridge
# 5                                 University of Oxford
# 6                      UCL (University College London)
# 7                              Imperial College London
# 8                                University of Chicago
# 9    ETH Zurich - Swiss Federal Institute of Techno...
# 10    Nanyang Technological University Singapore (NTU)
# 11     Ecole Polytechnique Fédérale de Lausanne (EPFL)
# 12                                Princeton University
# 13                                  Cornell University
# 14              National University of Singapore (NUS)
# 15                                     Yale University
# 16                            Johns Hopkins University
# 17                                 Columbia University
# 18                          University of Pennsylvania
# 19                  The Australian National University
# 20                              University of Michigan
# 21                                     Duke University
# 22                         The University of Edinburgh
# 24                                 Tsinghua University
# 25                         The University of Hong Kong
# 26             University of California Berkeley (UCB)
# 27                             The University of Tokyo
# 28                             Northwestern University
# 29   The Hong Kong University of Science and Techno...
# 30                               University of Toronto
# ..                                                 ...
# 141                             RWTH Aachen University
# 142                                 University of Oslo
# 143                           University of Pittsburgh
# 146                             University of Lausanne
# 147                                   Emory University
# 148                       Erasmus University Rotterdam
# 149                          Michigan State University
# 150                                University of Basel
# 153             Université catholique de Louvain (UCL)
# 154                               University of Vienna
# 157                   École Normale Supérieure de Lyon
# 158                           The University of Exeter
# 159                             University of Aberdeen
# 162                               Newcastle University
# 163                            University of Minnesota
# 164                    University of California Irvine
# 167                                 University of Bern
# 169                                  Dartmouth College
# 175                            University of Liverpool
# 176                             University of Virginia
# 179                              University of Florida
# 180                               University of Twente
# 181                            University of Göttingen
# 183                     University of Colorado Boulder
# 186                            University of Rochester
# 191                            University of Cape Town
# 192                   Scuola Normale Superiore di Pisa
# 195                               Stockholm University
# 197                               Texas A&M University
# 199                              Maastricht University
#
#      10 - Number of students  2 - Rank #1  3 - Rank #2     4 - Country  \
# 0                    11177.0          1.0          5.0   United States
# 1                    15845.0          2.0          3.0   United States
# 2                    20326.0          3.0          6.0   United States
# 3                     2209.0          4.0          3.0   United States
# 4                    18389.0          5.0          2.0  United Kingdom
# 5                    20409.0          6.0          1.0  United Kingdom
# 6                    30304.0          7.0         16.0  United Kingdom
# 7                    15857.0          8.0          8.0  United Kingdom
# 8                    13525.0          9.0          9.0   United States
# 9                    19233.0         10.0         10.0     Switzerland
# 10                   25499.0         11.0         52.0       Singapore
# 11                    9928.0         12.0         38.0     Switzerland
# 12                    7955.0         13.0          7.0   United States
# 13                   21850.0         14.0         19.0   United States
# 14                   30602.0         15.0         22.0       Singapore
# 15                   12155.0         16.0         12.0   United States
# 16                   15498.0         17.0         13.0   United States
# 17                   26587.0         18.0         14.0   United States
# 18                   20361.0         19.0         10.0   United States
# 19                   15986.0         20.0         48.0       Australia
# 20                   41818.0         21.0         21.0   United States
# 21                   15256.0         21.0         17.0   United States
# 22                   26759.0         23.0         27.0  United Kingdom
# 24                   42089.0         25.0         30.0           China
# 25                   18364.0         26.0         40.0       Hong Kong
# 26                   36182.0         27.0         18.0   United States
# 27                   26000.0         28.0         46.0           Japan
# 28                   17466.0         28.0         20.0   United States
# 29                   10214.0         30.0         44.0       Hong Kong
# 30                   69427.0         31.0         22.0          Canada
# ..                       ...          ...          ...             ...
# 141                  43721.0        141.0         79.0         Germany
# 142                  27730.0        142.0        146.0          Norway
# 143                  26367.0        142.0        100.0   United States
# 146                  13065.0        146.0        152.0     Switzerland
# 147                  12649.0        147.0         98.0   United States
# 148                  22047.0        147.0         72.0     Netherlands
# 149                  44556.0        149.0         83.0   United States
# 150                  12729.0        149.0         95.0     Switzerland
# 153                  24451.0        153.0        129.0         Belgium
# 154                  35375.0        154.0        165.0         Austria
# 157                   2221.0        157.0        182.0          France
# 158                  19159.0        158.0        130.0  United Kingdom
# 159                  12055.0        158.0        185.0  United Kingdom
# 162                  20952.0        161.0        175.0  United Kingdom
# 163                  60949.0        163.0         56.0   United States
# 164                  30419.0        164.0         99.0   United States
# 167                  10449.0        167.0        105.0     Switzerland
# 169                   6100.0        169.0         89.0   United States
# 175                  19815.0        173.0        177.0  United Kingdom
# 176                  24055.0        173.0        113.0   United States
# 179                  46346.0        178.0        143.0   United States
# 180                   6697.0        179.0        179.0     Netherlands
# 181                  28554.0        181.0        113.0         Germany
# 183                  30780.0        182.0        100.0   United States
# 186                   9636.0        186.0        153.0   United States
# 191                  20775.0        191.0        171.0    South Africa
# 192                    515.0        192.0        184.0           Italy
# 195                  33156.0        195.0        134.0          Sweden
# 197                  56245.0        195.0        159.0   United States
# 199                  16727.0        200.0        103.0     Netherlands
#
#         5 - Region  6 - Percentage of international #1  \
# 0    North America                                34.0
# 1    North America                                23.0
# 2    North America                                23.0
# 3    North America                                29.0
# 4           Europe                                36.0
# 5           Europe                                37.0
# 6           Europe                                48.0
# 7           Europe                                54.0
# 8    North America                                25.0
# 9           Europe                                38.0
# 10            Asia                                28.0
# 11          Europe                                57.0
# 12   North America                                22.0
# 13   North America                                25.0
# 14            Asia                                27.0
# 15   North America                                20.0
# 16   North America                                25.0
# 17   North America                                32.0
# 18   North America                                21.0
# 19         Oceania                                38.0
# 20   North America                                17.0
# 21   North America                                19.0
# 22          Europe                                38.0
# 24            Asia                                11.0
# 25            Asia                                41.0
# 26   North America                                17.0
# 27            Asia                                10.0
# 28   North America                                18.0
# 29            Asia                                 NaN
# 30   North America                                30.0
# ..             ...                                 ...
# 141         Europe                                19.0
# 142         Europe                                15.0
# 143  North America                                 NaN
# 146         Europe                                25.0
# 147  North America                                17.0
# 148         Europe                                22.0
# 149  North America                                 NaN
# 150         Europe                                27.0
# 153         Europe                                18.0
# 154         Europe                                31.0
# 157         Europe                                11.0
# 158         Europe                                27.0
# 159         Europe                                35.0
# 162         Europe                                26.0
# 163  North America                                11.0
# 164  North America                                27.0
# 167         Europe                                15.0
# 169  North America                                15.0
# 175         Europe                                34.0
# 176  North America                                 9.0
# 179  North America                                10.0
# 180         Europe                                24.0
# 181         Europe                                12.0
# 183  North America                                 9.0
# 186  North America                                 NaN
# 191         Africa                                17.0
# 192         Europe                                 9.0
# 195         Europe                                 9.0
# 197  North America                                 NaN
# 199         Europe                                50.0
#
#      7 - Percentage of international #2  8 - Ratio Student /Staff #1  \
# 0                                  34.0                     3.711268
# 1                                  22.0                     3.705484
# 2                                  26.0                     5.156092
# 3                                  27.0                     2.366212
# 4                                  35.0                     3.418944
# 5                                  38.0                     2.921481
# 6                                  49.0                     4.898345
# 7                                  55.0                     4.094148
# 8                                  25.0                     5.535729
# 9                                  38.0                     7.999596
# 10                                 31.0                     5.933149
# 11                                 55.0                     6.102065
# 12                                 24.0                     8.012910
# 13                                 24.0                     8.058867
# 14                                 30.0                     6.409714
# 15                                 21.0                     2.510526
# 16                                 24.0                     3.618557
# 17                                 32.0                     4.046696
# 18                                 20.0                     3.753228
# 19                                 35.0                     9.026250
# 20                                 16.0                     6.336760
# 21                                 22.0                     5.214432
# 22                                 40.0                     6.880982
# 24                                  9.0                     6.592808
# 25                                 42.0                     6.711155
# 26                                 17.0                    11.051792
# 27                                 10.0                     6.043199
# 28                                 18.0                     4.413850
# 29                                 31.0                          NaN
# 30                                 17.0                     7.536478
# ..                                  ...                          ...
# 141                                18.0                    14.016688
# 142                                19.0                     9.686728
# 143                                10.0                          NaN
# 146                                25.0                     6.182697
# 147                                19.0                     5.020313
# 148                                20.0                    11.572849
# 149                                17.0                          NaN
# 150                                27.0                    12.158940
# 153                                19.0                    19.915505
# 154                                26.0                    13.476107
# 157                                13.0                     5.287958
# 158                                28.0                    11.816059
# 159                                36.0                     9.164122
# 162                                30.0                     8.926277
# 163                                11.0                    12.145151
# 164                                21.0                    16.693146
# 167                                15.0                     9.179181
# 169                                15.0                     6.628328
# 175                                35.0                     9.232218
# 176                                12.0                     8.593065
# 179                                 9.0                     8.393615
# 180                                27.0                    10.254945
# 181                                12.0                     8.265905
# 183                                10.0                     8.200543
# 186                                29.0                          NaN
# 191                                18.0                    11.305828
# 192                                 7.0                     6.186047
# 195                                 8.0                    13.129526
# 197                                 9.0                          NaN
# 199                                50.0                    12.830854
#
#      9 - Ratio Student /Staff #2
# 0                            8.7
# 1                            7.5
# 2                            8.9
# 3                            6.5
# 4                           10.9
# 5                           11.2
# 6                           10.5
# 7                           11.4
# 8                            6.2
# 9                           14.6
# 10                          16.3
# 11                          11.2
# 12                           8.3
# 13                           9.8
# 14                          17.0
# 15                           4.3
# 16                           4.3
# 17                           6.1
# 18                           6.5
# 19                          19.3
# 20                           8.6
# 21                           4.5
# 22                          12.5
# 24                          13.7
# 25                          18.0
# 26                          13.1
# 27                           6.7
# 28                          12.8
# 29                          23.1
# 30                          18.7
# ..                           ...
# 141                         57.7
# 142                         18.6
# 143                          5.9
# 146                         13.6
# 147                          4.4
# 148                         20.1
# 149                         17.0
# 150                         17.7
# 153                         37.8
# 154                         20.8
# 157                          8.5
# 158                         17.5
# 159                         13.9
# 162                         15.6
# 163                         17.4
# 164                         17.0
# 167                         16.5
# 169                          6.6
# 175                         11.7
# 176                          9.7
# 179                         17.5
# 180                         12.8
# 181                         27.9
# 183                         16.3
# 186                          4.3
# 191                         11.7
# 192                          5.2
# 195                         24.9
# 197                         23.6
# 199                         18.0
#
# [144 rows x 10 columns]

# %% [markdown]
# Find useful insights in the data by performing an exploratory analysis. Can you find a strong correlation between any pair of variables in the dataset you just created? Example: when a university is strong in its international dimension, can you observe a consistency both for students and faculty members?

# %%
Rank.corr()
# Out:
#                                       number of international members  \
# number of international members                              1.000000
# number of international students                             0.643111
# number of members                                            0.598862
# number of students                                           0.319257
# rank_display                                                -0.536084
# ratio inter student/ all student                             0.427714
# ratio student/ staff                                        -0.310785
# No. of students per staff                                   -0.018654
# Number of Students                                           0.298825
# Percentage of International Students                         0.319920
# rank                                                        -0.362325
#
#                                       number of international students  \
# number of international members                               0.643111
# number of international students                              1.000000
# number of members                                             0.474219
# number of students                                            0.560282
# rank_display                                                 -0.313980
# ratio inter student/ all student                              0.543804
# ratio student/ staff                                          0.183565
# No. of students per staff                                     0.303051
# Number of Students                                            0.582886
# Percentage of International Students                          0.425958
# rank                                                         -0.263888
#
#                                       number of members  number of students  \
# number of international members                0.598862            0.319257
# number of international students               0.474219            0.560282
# number of members                              1.000000            0.772760
# number of students                             0.772760            1.000000
# rank_display                                  -0.328768           -0.050564
# ratio inter student/ all student              -0.068005           -0.164838
# ratio student/ staff                          -0.278744            0.306221
# No. of students per staff                     -0.097490            0.361916
# Number of Students                             0.621534            0.979522
# Percentage of International Students          -0.122098           -0.259594
# rank                                          -0.112106            0.005003
#
#                                       rank_display  \
# number of international members          -0.536084
# number of international students         -0.313980
# number of members                        -0.328768
# number of students                       -0.050564
# rank_display                              1.000000
# ratio inter student/ all student         -0.365100
# ratio student/ staff                      0.386302
# No. of students per staff                 0.296593
# Number of Students                       -0.101102
# Percentage of International Students     -0.187262
# rank                                     -0.166548
#
#                                       ratio inter student/ all student  \
# number of international members                               0.427714
# number of international students                              0.543804
# number of members                                            -0.068005
# number of students                                           -0.164838
# rank_display                                                 -0.365100
# ratio inter student/ all student                              1.000000
# ratio student/ staff                                         -0.098856
# No. of students per staff                                     0.004843
# Number of Students                                           -0.217077
# Percentage of International Students                          0.953941
# rank                                                         -0.338641
#
#                                       ratio student/ staff  \
# number of international members                  -0.310785
# number of international students                  0.183565
# number of members                                -0.278744
# number of students                                0.306221
# rank_display                                      0.386302
# ratio inter student/ all student                 -0.098856
# ratio student/ staff                              1.000000
# No. of students per staff                         0.561077
# Number of Students                                0.394936
# Percentage of International Students             -0.119842
# rank                                              0.188763
#
#                                       No. of students per staff  \
# number of international members                       -0.018654
# number of international students                       0.303051
# number of members                                     -0.097490
# number of students                                     0.361916
# rank_display                                           0.296593
# ratio inter student/ all student                       0.004843
# ratio student/ staff                                   0.561077
# No. of students per staff                              1.000000
# Number of Students                                     0.257120
# Percentage of International Students                  -0.120413
# rank                                                   0.107456
#
#                                       Number of Students  \
# number of international members                 0.298825
# number of international students                0.582886
# number of members                               0.621534
# number of students                              0.979522
# rank_display                                   -0.101102
# ratio inter student/ all student               -0.217077
# ratio student/ staff                            0.394936
# No. of students per staff                       0.257120
# Number of Students                              1.000000
# Percentage of International Students           -0.289970
# rank                                           -0.151891
#
#                                       Percentage of International Students  \
# number of international members                                   0.319920
# number of international students                                  0.425958
# number of members                                                -0.122098
# number of students                                               -0.259594
# rank_display                                                     -0.187262
# ratio inter student/ all student                                  0.953941
# ratio student/ staff                                             -0.119842
# No. of students per staff                                        -0.120413
# Number of Students                                               -0.289970
# Percentage of International Students                              1.000000
# rank                                                             -0.214197
#
#                                           rank
# number of international members      -0.362325
# number of international students     -0.263888
# number of members                    -0.112106
# number of students                    0.005003
# rank_display                         -0.166548
# ratio inter student/ all student     -0.338641
# ratio student/ staff                  0.188763
# No. of students per staff             0.107456
# Number of Students                   -0.151891
# Percentage of International Students -0.214197
# rank                                  1.000000

# %% [markdown]
#  The ranking one is based on the ratio of international student (less international leads to worst ranking)
#  and on the ratio of student staff 1 (higher ratio worst ranking)  (which seems different from the second)
#  other very important features are not captured here (number of publications, proportion of job found right after, .. etc).
#
#  And also we can notice that the Ratio Student staff between the two sites are not correlated which means that the values are different.

# %% [markdown]
# I propose to do a ranking composed of 30% of the first 30% of the second and 15% of the ranking percentage student and  25% on the ratio student/staff#1. We keep a strong relation to the two rankings because they have underlying informations that we do not have access to. We add a percentage of the student/staff which is important according to us and a another small pecentage of the (inverse because as the ratio is grwoing, the ranking too) international student.
# It is indeed arbitrary but with no further information all ranking made will be arbitrary.

# %%
#all ratio used are normalized in order to be compared
#then we just sort the sum and create a ranking on that
Myranking=Rank_final.copy()
Myranking['2 - Rank #1']=Rank_final['2 - Rank #1']/sum(Rank_final['2 - Rank #1'])
Myranking['3 - Rank #2']=Rank_final['3 - Rank #2']/sum(Rank_final['3 - Rank #2'])
Myranking['6 - Percentage of international #1']=1/Rank_final['6 - Percentage of international #1']/np.nansum(1/Rank_final['6 - Percentage of international #1'])
Myranking['8 - Ratio Student /Staff #1']=Rank_final['8 - Ratio Student /Staff #1']/np.nansum(Rank_final['8 - Ratio Student /Staff #1'])

Myranking['My ranking']=0.3*Myranking['2 - Rank #1']+0.3*Myranking['3 - Rank #2']\
                        +0.25*Myranking['8 - Ratio Student /Staff #1']+0.15*Myranking['6 - Percentage of international #1']

Myranking=Myranking.sort_values('My ranking')
a=list(Myranking['My ranking'].values)
index = [a.index(v)+1 for v in a]
Myranking['FinalRanking']=index
MyfinalRank = pd.DataFrame({'0 - School Name' : Rank['School name'],
                     '1 - Rank Perso': Myranking['FinalRanking'],
                     '2 - Rank #1' : Rank['rank_display'],
                     '3 - Rank #2' : Rank['rank'],
                     '4 - Country' : Rank['Country'],
                     '5 - Region' : Rank['region_x'],
                     '6 - Percentage of international' : round(Rank['ratio inter student/ all student']), 
                     '7 - Ratio Student /Staff #1' : Rank['ratio student/ staff'],
                     '8 - Ratio Student /Staff #2' : Rank['No. of students per staff'],
                     '9 - Number of students': Rank['Number of Students']})

MyfinalRank=MyfinalRank.sort_values('1 - Rank Perso')
display(MyfinalRank.head())
# Out:
#                                 0 - School Name  1 - Rank Perso  2 - Rank #1  \
# 5                          University of Oxford             1.0          6.0
# 3  California Institute of Technology (Caltech)             2.0          4.0
# 4                       University of Cambridge             3.0          5.0
# 0   Massachusetts Institute of Technology (MIT)             4.0          1.0
# 7                       Imperial College London             5.0          8.0
#
#    3 - Rank #2     4 - Country     5 - Region  \
# 5          1.0  United Kingdom         Europe
# 3          3.0   United States  North America
# 4          2.0  United Kingdom         Europe
# 0          5.0   United States  North America
# 7          8.0  United Kingdom         Europe
#
#    6 - Percentage of international  7 - Ratio Student /Staff #1  \
# 5                             37.0                     2.921481
# 3                             29.0                     2.366212
# 4                             36.0                     3.418944
# 0                             34.0                     3.711268
# 7                             54.0                     4.094148
#
#    8 - Ratio Student /Staff #2  9 - Number of students
# 5                         11.2                 20409.0
# 3                          6.5                  2209.0
# 4                         10.9                 18389.0
# 0                          8.7                 11177.0
# 7                         11.4                 15857.0

# %%
MyfinalRank.corr()
# Out:
#                                  1 - Rank Perso  2 - Rank #1  3 - Rank #2  \
# 1 - Rank Perso                         1.000000     0.844330     0.785899
# 2 - Rank #1                            0.844330     1.000000    -0.166548
# 3 - Rank #2                            0.785899    -0.166548     1.000000
# 6 - Percentage of international       -0.427603    -0.367227    -0.338549
# 7 - Ratio Student /Staff #1            0.462710     0.386302     0.188763
# 8 - Ratio Student /Staff #2            0.222892     0.296593     0.107456
# 9 - Number of students                 0.049565    -0.101102    -0.151891
#
#                                  6 - Percentage of international  \
# 1 - Rank Perso                                         -0.427603
# 2 - Rank #1                                            -0.367227
# 3 - Rank #2                                            -0.338549
# 6 - Percentage of international                         1.000000
# 7 - Ratio Student /Staff #1                            -0.100475
# 8 - Ratio Student /Staff #2                             0.001415
# 9 - Number of students                                 -0.218669
#
#                                  7 - Ratio Student /Staff #1  \
# 1 - Rank Perso                                      0.462710
# 2 - Rank #1                                         0.386302
# 3 - Rank #2                                         0.188763
# 6 - Percentage of international                    -0.100475
# 7 - Ratio Student /Staff #1                         1.000000
# 8 - Ratio Student /Staff #2                         0.561077
# 9 - Number of students                              0.394936
#
#                                  8 - Ratio Student /Staff #2  \
# 1 - Rank Perso                                      0.222892
# 2 - Rank #1                                         0.296593
# 3 - Rank #2                                         0.107456
# 6 - Percentage of international                     0.001415
# 7 - Ratio Student /Staff #1                         0.561077
# 8 - Ratio Student /Staff #2                         1.000000
# 9 - Number of students                              0.257120
#
#                                  9 - Number of students
# 1 - Rank Perso                                 0.049565
# 2 - Rank #1                                   -0.101102
# 3 - Rank #2                                   -0.151891
# 6 - Percentage of international               -0.218669
# 7 - Ratio Student /Staff #1                    0.394936
# 8 - Ratio Student /Staff #2                    0.257120
# 9 - Number of students                         1.000000
